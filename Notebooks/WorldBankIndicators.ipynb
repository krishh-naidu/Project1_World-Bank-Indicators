# %%
# Import required package libraries

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the file
Countries_gdp = pd.read_csv('Data Files/Countries_GDP.csv')

# %%
# Display Dataframe
Countries_gdp
# Out:
#                                          Country Name Country Code  \
# 0                                         Afghanistan          AFG
# 1                                             Albania          ALB
# 2                                             Algeria          DZA
# 3                                             Andorra          AND
# 4                                              Angola          AGO
# ..                                                ...          ...
# 201                                               NaN          NaN
# 202                                               NaN          NaN
# 203                                               NaN          NaN
# 204  Data from database: World Development Indicators          NaN
# 205                          Last Updated: 10/15/2020          NaN
#
#                Series Name        Series Code     2000 [YR2000]  \
# 0    GDP growth (annual %)  NY.GDP.MKTP.KD.ZG                ..
# ...

# %% [markdown]
# #### Dataset Cleaning process

# %%
# Rename Year columns
Countries_gdp = Countries_gdp.rename(columns={'2000 [YR2000]':'2000',
                             '2001 [YR2001]':'2001',
                             '2002 [YR2002]':'2002',
                             '2003 [YR2003]':'2003',
                             '2004 [YR2004]':'2004',
                             '2005 [YR2005]':'2005',
                             '2006 [YR2006]':'2006',
                             '2007 [YR2007]':'2007',
                             '2008 [YR2008]':'2008',
                             '2009 [YR2009]':'2009',
                             '2010 [YR2010]':'2010',
                             '2011 [YR2011]':'2011',
                             '2012 [YR2012]':'2012',
                             '2013 [YR2013]':'2013',
                             '2014 [YR2014]':'2014',
                             '2015 [YR2015]':'2015',
                             '2016 [YR2016]':'2016',
                             '2017 [YR2017]':'2017',
                             '2018 [YR2018]':'2018',
                             '2019 [YR2019]':'2019'})

# %%
# Remove any rows with no vlaues
Countries_gdp_clean=Countries_gdp.dropna(how='any')

# %%
# Remove Unwanted columns
Countries_gdp_clean = Countries_gdp_clean.drop(columns=['Series Name','Series Code','Country Code'])

# %%
Countries_gdp_clean
# Out:
#                  Country Name               2000              2001  \
# 0                 Afghanistan                 ..                ..
# 1                     Albania   6.95003613422918  8.29007002725659
# 2                     Algeria                3.8                 3
# 3                     Andorra   3.52836129711103  8.11935772169949
# 4                      Angola   3.05462423430785   4.2059985561951
# ..                        ...                ...               ...
# 196                   Vietnam   6.78731640822197   6.1928933118123
# 197               Yemen, Rep.    6.1819155928913  3.80364587188127
# 198                    Zambia   3.89732294341896  5.31686827418419
# 199                  Zimbabwe  -3.05918976180379  1.43961538448976
# 200  Central African Republic  -2.48943244028874  4.46473902640867
#
#                   2002               2003               2004  \
# 0                   ..   8.83227780370231   1.41411798021916
# ...

# %%
# Replace any empty values with spaces so it allows us to covert all columns into float data type

Countries_gdp_clean = Countries_gdp_clean.replace({'..':''})

# %%
Countries_gdp_clean
# Out:
#                  Country Name               2000              2001  \
# 0                 Afghanistan
# 1                     Albania   6.95003613422918  8.29007002725659
# 2                     Algeria                3.8                 3
# 3                     Andorra   3.52836129711103  8.11935772169949
# 4                      Angola   3.05462423430785   4.2059985561951
# ..                        ...                ...               ...
# 196                   Vietnam   6.78731640822197   6.1928933118123
# 197               Yemen, Rep.    6.1819155928913  3.80364587188127
# 198                    Zambia   3.89732294341896  5.31686827418419
# 199                  Zimbabwe  -3.05918976180379  1.43961538448976
# 200  Central African Republic  -2.48943244028874  4.46473902640867
#
#                   2002               2003               2004  \
# 0                        8.83227780370231   1.41411798021916
# 1     4.53996064044719   5.53005077793323    5.5099986931984
# ...

# %%
columns=['2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011',
         '2012','2013','2014','2015','2016','2017','2018','2019']

# %%
# Convert all columns into float so we can run mathmatial calculations
Countries_gdp_clean[columns] = Countries_gdp_clean[columns].apply(pd.to_numeric)

# %%
#pd.set_option('display.max_rows', 201)
Countries_gdp_clean
# Out:
#                  Country Name      2000      2001       2002       2003  \
# 0                 Afghanistan       NaN       NaN        NaN   8.832278
# 1                     Albania  6.950036  8.290070   4.539961   5.530051
# 2                     Algeria  3.800000  3.000000   5.600000   7.200000
# 3                     Andorra  3.528361  8.119358   4.546362   8.694204
# 4                      Angola  3.054624  4.205999  13.665687   2.989850
# ..                        ...       ...       ...        ...        ...
# 196                   Vietnam  6.787316  6.192893   6.320821   6.899063
# 197               Yemen, Rep.  6.181916  3.803646   3.935232   3.747398
# 198                    Zambia  3.897323  5.316868   4.506014   6.944974
# 199                  Zimbabwe -3.059190  1.439615  -8.894024 -16.995075
# 200  Central African Republic -2.489432  4.464739   3.616542  -5.397485
#
#           2004       2005       2006       2007       2008  ...       2010  \
# ...

# %%
# Calculate average World GDP growth % for years 2000 - 2019
gdp_mean = []
years=[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,
         2012,2013,2014,2015,2016,2017,2018,2019]
for i in columns:
    gdp_mean.append(Countries_gdp_clean[str(i)].mean())

# %%
# Preapre a Dataframe for Year and GDP Growth
world_gdp_growth = pd.DataFrame()
world_gdp_growth['Years'] = years
world_gdp_growth['GDP Growth(annual %)'] = gdp_mean
world_gdp_growth
# Out:
#     Years  GDP Growth(annual %)
# 0    2000              4.146986
# 1    2001              3.452776
# 2    2002              3.267761
# 3    2003              3.831897
# 4    2004              5.756994
# 5    2005              5.043367
# 6    2006              5.811171
# 7    2007              5.654778
# 8    2008              3.842026
# 9    2009             -0.094909
# 10   2010              4.152570
# 11   2011              3.522751
# 12   2012              3.587705
# 13   2013              3.331517
# 14   2014              3.391426
# 15   2015              2.856537
# 16   2016              3.085232
# 17   2017              3.222830
# 18   2018              3.156803
# 19   2019              2.786354

# %%
# Do a line plot using matplotlib

plt.style.use('seaborn-ticks') # using seaborn-ticks style
x_axis=world_gdp_growth['Years'] # preparing x-axis
y_axis=world_gdp_growth['GDP Growth(annual %)'] # preparing y-axis

plt.figure(figsize=(12,8)) # fig size
plt.plot(x_axis,y_axis,lw=3,
         clip_on=True,marker='o')


for x,y in zip(x_axis,y_axis):
    label = "{:.2f}".format(y)
    plt.annotate(label,# this is the text
                 (x,y),# this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,12), # distance from text to points (x,y)
                 ha='center')

    
plt.title('World GDP Growth',fontsize=18, color='Blue')
plt.ylabel('GDP %',fontsize=18, color='green')
plt.xlabel('Years',fontsize=18, color='green')
plt.legend()
   

    
plt.grid()
plt.show()
#plt.axis([2000,2019,0,6])
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### On Second part, Trying plot all coountries on GMAP

# %%
# Prepare a Data frame with countries list
country_list = Countries_gdp_clean['Country Name']

# %%
# Dependencies
import requests
import json

# Google developer API key
from config import gkey

# Target city
target_country = country_list

# %%
pwd
# Out:
# '/Users/ramakrishnadevarakonda/Desktop/Project1_World-Bank-Indicators/Notebooks'

# %%
# Renaming Egypt and Yemen to match GMAP name
country_list[53] = 'Egypt'
country_list[197] = 'Yemen'
country_list
# Out:
# <ipython-input-22-ed2b0f07af6c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_list[53] = 'Egypt'
# <ipython-input-22-ed2b0f07af6c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country
831239, 26.820553, 13.794185, 1.650801, 15.179384, 58.595272, -26.522503, 9.145000000000001, -17.713371, 61.92410999999999, 46.227638, -0.803689, 13.443182, 32.1656221, 51.165691, 7.946527, 39.074208, 71.706936, 12.1165, 13.444304, 15.783471, 9.945587, 4.860416, 18.971187, 15.199999, 22.3193039, 47.162494, 64.963051, 20.593684, -0.789275, 38.906374, 33.223191, 53.1423672, 31.046051, 41.8
# ...

# %%
# Uisng GMAPS we are colouring global map using GINI codes


import gmaps
import gmaps.geojson_geometries
from config import gkey
gmaps.configure(api_key=gkey)
import pandas as pd
import gmaps.datasets
from matplotlib.cm import viridis
from matplotlib.colors import to_hex

# Get all the countries with geometry coordinates
countries_geojson = gmaps.geojson_geometries.load_geometry('countries')

# to get all the GINI values for each country
rows = gmaps.datasets.load_dataset('gini') # 'rows' is a list of tuples
country2gini = dict(rows) # dictionary mapping 'country' -> gini coefficient



# We will need to scale the GINI values to lie between 0 and 1
min_gini = min(country2gini.values())
max_gini = max(country2gini.values())
gini_range = max_gini - min_gini


def calculate_color(gini):
    """
    Convert the GINI coefficient to a color
    """
    # make gini a number between 0 and 1
    normalized_gini = (gini - min_gini) / gini_range

    # invert gini so that high inequality gives dark color
    inverse_gini = 1.0 - normalized_gini

    # transform the gini coefficient to a matplotlib color
    mpl_color = viridis(inverse_gini)

    # transform from a matplotlib color to a valid CSS color
    gmaps_color = to_hex(mpl_color, keep_alpha=False)

    return gmaps_color

colors = []
for feature in countries_geojson['features']:
    country_name = feature['properties']['name']
    try:
        gini = country2gini[country_name]
        color = calculate_color(gini)
    except KeyError:
        # no GINI for that country: return default color
        color = (0, 0, 0, 0.3)
    colors.append(color)

# %%
# Create a DF for lat & lng
latlng = pd.DataFrame({'Latitude':latitude,'Longitude':longitude})
latlng
# Out:
#       Latitude   Longitude
# 0    33.939110   67.709953
# 1    41.153332   20.168331
# 2    28.033886    1.659626
# 3    42.506285    1.521801
# 4   -11.202692   17.873887
# ..         ...         ...
# 196  14.058324  108.277199
# 197  15.552727   48.516388
# 198 -13.133897   27.849332
# 199 -19.015438   29.154857
# 200   6.611111   20.939444
#
# [201 rows x 2 columns]

# %%
locations = latlng[['Latitude','Longitude']]
df = pd.DataFrame({'Country':Countries_gdp_clean['Country Name'],
                  'GDP':Countries_gdp_clean['2019']})
df.fillna(0)
country_gdp = df.to_dict('records')

info_box_template = """
<dl>
<dt>Country</dt><dd>{Country}</dd>
<dt>2019 GDP</dt><dd>{GDP}</dd>
</dl>
"""
gdp_info = [info_box_template.format(**row) for row in country_gdp]

fig = gmaps.figure()
gini_layer = gmaps.geojson_layer(
    countries_geojson,
    fill_color=colors,
    stroke_color=colors,
    fill_opacity=0.8)
fig.add_layer(gini_layer)
fig.add_layer(gmaps.marker_layer(locations,info_box_content=gdp_info))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
df = pd.DataFrame({'Country':Countries_gdp_clean['Country Name'],
                  'GDP':Countries_gdp_clean['2019']})
df.fillna(0)
country_gdp = df.to_dict('records')

info_box_template = """
<dl>
<dt>Country</dt><dd>{Country}</dd>
<dt>2019 GDP</dt><dd>{GDP}</dd>
</dl>
"""

locations = latlng[['Latitude','Longitude']]

gdp_info = [info_box_template.format(**row) for row in country_gdp]


marker_layer = gmaps.marker_layer(locations, info_box_content=gdp_info)
fig = gmaps.figure()
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
