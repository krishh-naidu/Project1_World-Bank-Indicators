# %%
# Import required libs
import pandas as pd

# %%
datafile = 'Data Files/data.json'

# %%
df = pd.read_json(datafile,orient='records')

# %%
df
# Out:
#                                                    description  data
# title        Global Land and Ocean Temperature Anomalies, S...   NaN
# units                                          Degrees Celsius   NaN
# base_period                                          1901-2000   NaN
# missing                                                   -999   NaN
# 1880                                                       NaN -0.11
# ...                                                        ...   ...
# 2016                                                       NaN  0.95
# 2017                                                       NaN  0.86
# 2018                                                       NaN  0.83
# 2019                                                       NaN  0.94
# 2020                                                       NaN  0.97
#
# [145 rows x 2 columns]

# %% [markdown]
# ### Data Cleansing Part

# %%
# Remove unwanted column
del df['description']

# %%
#Drop if there are any missing values
df = df.dropna(how='any')

# %%
df.set_index=None

# %%
x = df.index
x
y=df['data']
y
# Out:
# 1880   -0.11
# 1881   -0.16
# 1882   -0.10
# 1883   -0.18
# 1884   -0.29
#         ...
# 2016    0.95
# 2017    0.86
# 2018    0.83
# 2019    0.94
# 2020    0.97
# Name: data, Length: 141, dtype: float64

# %%
# Import Bokeh Libraries
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
output_notebook()
from bokeh.models import ColumnDataSource

from bokeh.models import HoverTool

source = ColumnDataSource(
        data=dict(
            x=df.index,
            y=df['data']
        )
    )

hover = HoverTool(
        tooltips=[
            
            ("Temp:", "$y")
        ]
    )

p = figure(plot_width=800, plot_height=400, tools=[hover], title="Global Land and Ocean Temperatures Anomalies")

p.line('x', 'y', line_width=2, source=source,legend_label='Years',line_color='red')
p.circle('x','y',fill_color='white',size=8,source=source)


show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1401">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c558bfd4-c4ab-4c7f-abad-5c8e7ef2f49f" data-root-id="1404"></div>

# %%
import numpy as np
from bokeh.models.annotations import Span
from math import pi

data = list((df.index))
y = df['data']

from bokeh.models import HoverTool

x = df.index
y = df['data']

hover = HoverTool(
        tooltips=[
            
            ("Temp:", "$y")
        ]
    )

# Set the x_range to the list of categories above
p = figure(y_range=(-1,1),x_range=(data), plot_height=250,plot_width=800,tools=[hover], title="Global Land and Ocean Temperatures Anomalies")

# Categorical values can also be used as coordinates
p.vbar(x=(data), top=y, width=0.2,)

lower = Span(location=0, dimension='width', line_color='firebrick', line_width=4)
p.add_layout(lower)

p.xaxis.major_label_orientation = pi/4
# Set some properties to make the plot look better
p.xgrid.grid_line_color = None
#p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="362a9f5e-df9f-41ef-8058-e643a7c5aa9b" data-root-id="1522"></div>
